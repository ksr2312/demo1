# %%
print('A Kishore kUMAR')
# Out:
# A Kishore kUMAR

# %%
x=10
y='Hello'
print(x)
print(y)
# Out:
# 10
# Hello

# %%
print(x,y)
# Out:
# 10 Hello

# %%
# shows only comment (shows only not executable data)

# %%
#the value of x is = 10
print('the value of x and y is = ',x,y)
# Out:
# the value of x and y is =  10 Hello

# %%
#the value of x is 10 and y is hello
print('the value of x is',x,'and y is',y)
# Out:
# the value of x is 10 and y is Hello

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# str

# %%
print(type(y))
# Out:
# <class 'str'>

# %%
z=10.5
type(z)
# Out:
# float

# %%
b=True
print(type(b))
# Out:
# <class 'bool'>

# %%
#True and False
